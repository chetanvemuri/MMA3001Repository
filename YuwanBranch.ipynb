# %% [markdown]
# <a href="https://colab.research.google.com/github/chetanvemuri/MMA3001Repository/blob/YuwanBranch/YuwanBranch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chetanvemuri/MMA3001Repository.git
# Out:
# fatal: destination path 'MMA3001Repository' already exists and is not an empty directory.
